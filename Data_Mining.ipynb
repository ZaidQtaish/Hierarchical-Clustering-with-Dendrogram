# %% [markdown]
# <a href="https://colab.research.google.com/github/ZaidQtaish/Hierarchical-Clustering-with-Dendrogram/blob/main/Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

df = pd.read_csv("dendrogram_dataset.csv", index_col=0)

data = df.values

linked = linkage(data, method='ward')

plt.figure(figsize=(10, 6))
dendrogram(
    linked,
    labels=df.index.tolist(),
    color_threshold=7
)
plt.axhline(y=7, color='r', linestyle='--')

plt.title("Dendrogram from CSV File")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()
